# %%
import json

item_list = []
for i in range(9):
    with open('/home/orelit/Projects -Sathsara/Planigo/Models/VIT_CF/label2id_model{}.json'.format(i+1)) as json_file:
        data = json.load(json_file)
        barcodes = list(data.keys())
        for barcode in barcodes:
            item_list.append(barcode)
            
print(item_list)
# Out:
# ['038900014278', '5604912425040', '5705550300963', '693493034517', '7290000208213', '7290000208930', '7290000210360', '7290000210469', '7290000307237', '7290002019787', '7290002019794', '7290002057147', '7290002057475', '7290002057482', '7290002057628', '7290002929284', '7290003527380', '7290008175821', '7290010066001', '7290011593117', '7290011947262', '7290011947798', '7290014356368', '7290016401271', '7290016401424', '7290016517538', '7290017079608', '7290017105062', '7290017106076', '7290017142159', '7290017142166', '7290017142203', '7290017142418', '7290017142487', '7290017617046', '7290108502329', '7290108509250', '7290111350030', '7290112357076', '7290112357083', '7290113192348', '7290113192539', '7290113194298', '7290113195929', '7290113196780', '8004030845046', '8005110171215', '8032793342458', '8690777221405', '5900907000965', '7290000207162', '7290000208077', '7290000208336', '7290000303598', '7290002057123', '7290002057734', '7290002057864', '7290002111085', '729000211167
# ...

# %%
print([item for item, count in collections.Counter(item_list).items() if count > 1])
# Out:
# []

# %%
item_list = []
for i in range(4):
    with open('/home/orelit/Projects -Sathsara/Planigo/Models/VIT_Doody_new_2/label2id_section{}.json'.format(i+1)) as json_file:
        data = json.load(json_file)
        barcodes = list(data.keys())
        for barcode in barcodes:
            item_list.append(barcode)
            
print(item_list)
# Out:
# ['7290000168173', '7290110328764', '7290115259179', '7290115259209', '8715700115344', '7290000048185', '7290000522111', '7290006492432', '7290110324926', '7290110328771', '7290115259193', '7290115259261', '0861432329', '7290000307237', '7290004122195', '7290004131074', '7290017217611', '7290110328788', '7290115259186', '7290115259346', '11111111', '7290002824640', '7290004127077', '7290004127329', '7290011923303']

# %%
print([item for item, count in collections.Counter(item_list).items() if count > 1])
# Out:
# []

# %%
item_list = []

with open('/home/orelit/Projects -Sathsara/Planigo/Models/VIT_SL/label2id.json') as json_file:
    data = json.load(json_file)
    barcodes = list(data.keys())
    for barcode in barcodes:
        item_list.append(barcode)
        
print(item_list)
# Out:
# ['4791061000004', '4791111120317', '4791111152028', '4791111152226', '4792024005814', '4792024015684', '4792024015769', '4792037188115', '4792037767266', '4792068181130', '4792069001383', '4792081000937', '4792081001859', '4792081014040', '4792090000546', '4792143280314', '4792143280413', '4792143282417', '4792149097107', '4792225700976', '4792229216206', '4792240002536', '4792551000313', '4796002401001', '4796002403005', '4796002404002', '4796002405009', '4796006420183', '4796918130194', '4796918130712', '6005044001451', '6005044004070', '8888002086008', '8888101611262', '8888101612269', '8901030732911', '8901499007704', '93286']

# %%
print([item for item, count in collections.Counter(item_list).items() if count > 1])
# Out:
# []

# %%
models = ['black1','black2','black3','black4','black_red1','black_red2','black_red3','black_white1',
               'black_white2','black_white3','green1','green2','light_brown1','light_brown2','light_yellow1',
               'light_yellow2','other','red','white_and_blue']

item_list = []
for model in models:
    with open('/home/orelit/Projects -Sathsara/Planigo/Models/WINE_POLYGON2/label2id_{}.json'.format(model)) as json_file:
        data = json.load(json_file)
        barcodes = list(data.keys())
        for barcode in barcodes:
            item_list.append(barcode)
            
print(item_list)
# Out:
# ['7290002363491', '7290004494063', '7290004494131', '7290008802895', '7290008803090', '7290017289588', '7804414000877', '7804414017141', '8422443005213', '7290006256102', '7290008670142', '7290008802291', '7290008804189', '7290008805520', '7290016717235', '7290017647425', '7290101582366', '7290101582403', '7290103681173', '7290108620153', '7804414000860', '7290008802512', '7290008804332', '7290015781107', '7290017289175', '7290017289595', '7290017589763', '7290017589848', '7290017812052', '7290108620108', '7804414001614', '8002450206522', '7290008801010', '7290008805964', '7290008807777', '7290012576362', '7290015781091', '7290015781299', '7290017289120', '7290017589633', '7290018165294', '7290018294192', '7290000023809', '7290000024264', '7290000521008', '7290008801843', '7290014503137', '7290015781008', '7290015951227', '7290018294208', '7290108620177', '8002450206508', '7290000024202', '7290000521404', '7290004494148', '7290008670302', '7290008801157', '7290014466609', '7290015350
# ...

# %%
print([item for item, count in collections.Counter(item_list).items() if count > 1])
# Out:
# ['608614309160', '7290017812847', '7290005966033']

# %%
item_list = []
for i in range(6):
    with open('/home/orelit/Projects -Sathsara/Planigo/Models/cerial/cerial_model_{}.txt'.format(i+1)) as file:
        barcodes = [line.rstrip() for line in file]
        for barcode in barcodes:
            item_list.append(barcode)
            
print(item_list)
# Out:
# ['038527591053', '042400108153', '3387390320244', '5050083559761', '5053827193368', '5900020026552', '5900020037916', '7290000168173', '7290000169798', '7290000315140', '7290002543237', '7290107646925', '7290107647731', '7290107647823', '7290107647854', '7290109358765', '7290112491701', '7290112494351', '7290112494993', '7290112495006', '7290112495020', '7290112495037', '7290112495044', '7290112495228', '7290112495235', '7290112495433', '7290112495822', '7290116530185', '7290116530260', '7613030979647', '7613033548192', '7613035548374', '7613036387798', '7613038268262', '7613287654151', '884912002372', '884912288745', '884912342737', '884912365217', '0064144090020', '038527591060', '041190052837', '0884912180629', '3387390525960', '3387390730852', '4011800528416', '4011800567613', '4011800629519', '4011800633516', '5010026512055', '5010026512062', '5010026515919', '5010026515933', '5010026515940', '5010026519368', '5010029000016', '5010029221084', '5010029223484', '5053827215671', '5
# ...

# %%
print([item for item, count in collections.Counter(item_list).items() if count > 1])
# Out:
# []

# %%
item_list = []
with open('/home/orelit/Projects -Sathsara/Planigo/Models/beer_models_1.txt'.format(i+1)) as file:
    barcodes = [line.rstrip() for line in file]
    for barcode in barcodes:
        item_list.append(barcode)
        
print(item_list)
# Out:
# ['4066600999614', '4105120623941', '4105120624412', '5010038454831', '5010677551397', '5010677554398', '54079021', '5410316983693', '5410769200088', '697348758467', '7290000135625', '7290000135632', '7290001594858', '7290002871248', '7290006764058', '7290006764072', '7290006764157', '7290008464604', '7290008464673', '7290008464697', '7290008464741', '7290011132309', '7290013713032', '7290110113476', '7861500002818']

# %%
print([item for item, count in collections.Counter(item_list).items() if count > 1])
# Out:
# []
